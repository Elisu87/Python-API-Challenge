# %% [markdown]
# # Python API
#
# # Objective is to build a series of scatter plots to showcase the following relationships:
#
# - Temperature (F) vs. Latitude
# - Humidity (%) vs. Latitude
# - Cloudiness (%) vs. Latitude
# - Wind Speed (mph) vs. Latitude

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Select Random Cities
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
# Create Dataframe to hold city data
city_data= pd.DataFrame({"City": cities})

# Change Format to include First Letter as Capital Letter
city_data["City"]= city_data["City"].str.title()

# %%
#Add Columns empty columns to dataframe
city_data['Cloudiness'] = ""
city_data['Country'] = ""
city_data['Humidity'] = ""
city_data['Lat'] = ""
city_data['Lng'] = ""
city_data['Max Temp'] = ""
city_data['Wind Speed'] = ""

city_data.head()
# Out:
#           City Cloudiness Country Humidity Lat Lng Max Temp Wind Speed
# 0  La Macarena
# 1    Upernavik
# 2     Thompson
# 3  East London
# 4  Provideniya

# %%
# Save configuration and build query URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
from pprint import pprint

# %%
#print header 
print(f"Beginning Data Retrieval")
# get city from DataFrame

#use iterrows to iterate through pandas DataFrame
for index, row in city_data.iterrows():
    city_name = row['City']
   
    # assemble url and make API request
    response = requests.get(query_url + city_name).json()
    
    # Use exception handling in case any of our cities'  are missing
    # NOTE: if our code hits a KeyError or IndexError on ANY of the lines of code below, it will skip any unexecuted code and move to the next iteration
    try: 
        print(f"Processing Record {index} |{city_name}")
        
        city_data.loc[index, 'Cloudiness'] =  response['clouds']['all']
        city_data.loc[index, 'Country'] =  response['sys']['country']
        city_data.loc[index, 'Humidity'] = response['main']['humidity']
        city_data.loc[index, 'Lat'] =   response['coord']['lat']
        city_data.loc[index, 'Lng'] = response['coord']['lon']
        city_data.loc[index, 'Max Temp'] = response['main']['temp_max']
        city_data.loc[index, 'Wind Speed'] = response['wind']['speed']
       
    except (KeyError, IndexError):
        print("City not found. Skipping")
# Out:
# Beginning Data Retrieval
# Processing Record 0 |La Macarena
# Processing Record 1 |Upernavik
# Processing Record 2 |Thompson
# Processing Record 3 |East London
# Processing Record 4 |Provideniya
# Processing Record 5 |Tual
# Processing Record 6 |Ribeira Grande
# Processing Record 7 |Torbay
# Processing Record 8 |Lavrentiya
# Processing Record 9 |Clyde River
# Processing Record 10 |Saint-Philippe
# Processing Record 11 |Bluff
# Processing Record 12 |Port Hardy
# Processing Record 13 |Oudtshoorn
# Processing Record 14 |Buala
# Processing Record 15 |Wanning
# Processing Record 16 |Pontes E Lacerda
# Processing Record 17 |Airai
# Processing Record 18 |Yulara
# Processing Record 19 |Khani
# Processing Record 20 |Mahebourg
# Processing Record 21 |Mar Del Plata
# Processing Record 22 |Nueve De Julio
# Processing Record 23 |Fare
# Processing Record 24 |Bredasdorp
# Processing Record 25 |Paita
# Processing Record 26 |Jamestown
# Processing Record 27 |Cherskiy
# Processing Record 28 |Hobart
# Processing Record 29 |Kaeo
# Processing Record 30 |Itarema
# Processing Record 31 |Barrow
# Processing Record 32 |Mapiri
# Processing Record 33 |Tuktoyaktuk
# Processing Record 34 |Qaanaaq
# Processing Record 35 |Balkhash
# Processing Record 36 |Matara
# Processing Record 37 |Qeshm
# Processing Record 38 |Indramayu
# Processing Record 39 |Avarua
# Processing Record 40 |Cabo San Lucas
# Processing Record 41 |Negombo
# Processing Record 42 |Illoqqortoormiut
# City not found. Skipping
# Processing Record 43 |Mataura
# Processing Record 44 |Ostrovnoy
# Processing Record 45 |Copala
# Processing Record 46 |Ponta Do Sol
# Processing Record 47 |Yellowknife
# Processing Record 48 |Henties Bay
# Processing Record 49 |Pisco
# Processing Record 50 |Pokhara
# Processing Record 51 |Tsiroanomandidy
# Processing Record 52 |Lompoc
# Processing Record 53 |Dikson
# Processing Record 54 |Faanui
# Processing Record 55 |Auki
# Processing Record 56 |Hatillo
# Processing Record 57 |Ushuaia
# Processing Record 58 |Sembakung
# Processing Record 59 |Redwater
# Processing Record 60 |Butaritari
# Processing Record 61 |Sinnamary
# Processing Record 62 |Vaini
# Processing Record 63 |Inuvik
# Processing Record 64 |Severo-Kurilsk
# Processing Record 65 |High Rock
# Processing Record 66 |Lebu
# Processing Record 67 |Tingo Maria
# Processing Record 68 |Lorengau
# Processing Record 69 |Busselton
# Processing Record 70 |Mount Gambier
# Processing Record 71 |Avera
# Processing Record 72 |Krasnoarmeysk
# Processing Record 73 |Khlung
# Processing Record 74 |Nome
# Processing Record 75 |Rikitea
# Processing Record 76 |Pusad
# Processing Record 77 |Balabac
# Processing Record 78 |Danshui
# Processing Record 79 |Oistins
# Processing Record 80 |Havre-Saint-Pierre
# Processing Record 81 |Elat
# Processing Record 82 |Virginia Beach
# Processing Record 83 |Hermanus
# Processing Record 84 |Kapaa
# Processing Record 85 |Port Alfred
# Processing Record 86 |Jalu
# Processing Record 87 |Carnarvon
# Processing Record 88 |Hami
# Processing Record 89 |Kjollefjord
# Processing Record 90 |Yar-Sale
# Processing Record 91 |New Norfolk
# Processing Record 92 |Nanortalik
# Processing Record 93 |Simplicio Mendes
# Processing Record 94 |Saint George
# Processing Record 95 |Amderma
# City not found. Skipping
# Processing Record 96 |Noumea
# Processing Record 97 |Mehamn
# Processing Record 98 |Salym
# Processing Record 99 |Cairns
# Processing Record 100 |Srednekolymsk
# Processing Record 101 |Beyneu
# Processing Record 102 |Port Macquarie
# Processing Record 103 |Darhan
# Processing Record 104 |Necochea
# Processing Record 105 |Souillac
# Processing Record 106 |Albany
# Processing Record 107 |Manono
# Processing Record 108 |San Patricio
# Processing Record 109 |Plettenberg Bay
# Processing Record 110 |Kruisfontein
# Processing Record 111 |Palabuhanratu
# City not found. Skipping
# Processing Record 112 |Panjwin
# City not found. Skipping
# Processing Record 113 |Sitka
# Processing Record 114 |Srivardhan
# Processing Record 115 |Asfi
# Processing Record 116 |Louisbourg
# City not found. Skipping
# Processing Record 117 |Talaja
# Processing Record 118 |Sungairaya
# Processing Record 119 |Cape Town
# Processing Record 120 |Alipur
# Processing Record 121 |Castro
# Processing Record 122 |Manyana
# Processing Record 123 |Chuy
# Processing Record 124 |Warangal
# Processing Record 125 |Lieksa
# Processing Record 126 |Abu Kamal
# Processing Record 127 |Kushiro
# Processing Record 128 |Salalah
# Processing Record 129 |Hithadhoo
# Processing Record 130 |Khandyga
# Processing Record 131 |Belushya Guba
# City not found. Skipping
# Processing Record 132 |Arraial Do Cabo
# Processing Record 133 |Katsuura
# Processing Record 134 |Nikolskoye
# Processing Record 135 |Mulki
# Processing Record 136 |Oussouye
# Processing Record 137 |Caxito
# Processing Record 138 |Manta
# Processing Record 139 |Englewood
# Processing Record 140 |Nizhneyansk
# City not found. Skipping
# Processing Record 141 |Hirara
# Processing Record 142 |Guerrero Negro
# Processing Record 143 |San Pedro
# Processing Record 144 |Beroroha
# Processing Record 145 |Padang
# Processing Record 146 |Taolanaro
# City not found. Skipping
# Processing Record 147 |Hilo
# Processing Record 148 |Nsanje
# Processing Record 149 |Hamilton
# Processing Record 150 |Tumannyy
# City not found. Skipping
# Processing Record 151 |Penzance
# Processing Record 152 |Coquimbo
# Processing Record 153 |Saint Anthony
# Processing Record 154 |Marienburg
# Processing Record 155 |Wanxian
# Processing Record 156 |Punta Arenas
# Processing Record 157 |Adrar
# Processing Record 158 |Ballina
# Processing Record 159 |Caravelas
# Processing Record 160 |Charters Towers
# Processing Record 161 |Gravdal
# Processing Record 162 |Kavieng
# Processing Record 163 |Ankazobe
# Processing Record 164 |Puerto Ayora
# Processing Record 165 |Bambous Virieux
# Processing Record 166 |Morondava
# Processing Record 167 |Wadern
# Processing Record 168 |Port Elizabeth
# Processing Record 169 |Willowmore
# Processing Record 170 |Kostino
# Processing Record 171 |Benguela
# Processing Record 172 |Port Lincoln
# Processing Record 173 |Neftcala
# Processing Record 174 |Madison
# Processing Record 175 |Gondanglegi
# Processing Record 176 |Banda Aceh
# Processing Record 177 |Kiama
# Processing Record 178 |Omboue
# Processing Record 179 |Kirensk
# Processing Record 180 |Gongzhuling
# Processing Record 181 |Westport
# Processing Record 182 |Kahului
# Processing Record 183 |Grajau
# Processing Record 184 |Tasiilaq
# Processing Record 185 |Rio Grande
# Processing Record 186 |Kodiak
# Processing Record 187 |Longyearbyen
# Processing Record 188 |Bonavista
# Processing Record 189 |Zhanatas
# City not found. Skipping
# Processing Record 190 |Coria
# Processing Record 191 |Barentsburg
# City not found. Skipping
# Processing Record 192 |Bilma
# Processing Record 193 |Kaitangata
# Processing Record 194 |Portland
# Processing Record 195 |Atuona
# Processing Record 196 |Bethel
# Processing Record 197 |Saleaula
# City not found. Skipping
# Processing Record 198 |Mys Shmidta
# City not found. Skipping
# Processing Record 199 |Teacapan
# Processing Record 200 |Tiksi
# Processing Record 201 |Mendahara
# City not found. Skipping
# Processing Record 202 |Saldanha
# Processing Record 203 |Havoysund
# Processing Record 204 |Sao Filipe
# Processing Record 205 |Puerto Narino
# Processing Record 206 |Haines Junction
# Processing Record 207 |Musoma
# Processing Record 208 |Vanavara
# Processing Record 209 |Trapani
# Processing Record 210 |Kyshtovka
# Processing Record 211 |Oktyabrskiy
# Processing Record 212 |Le Mars
# Processing Record 213 |Guiratinga
# Processing Record 214 |Gayny
# Processing Record 215 |Dawei
# Processing Record 216 |Yartsevo
# Processing Record 217 |Tibacuy
# Processing Record 218 |Belmonte
# Processing Record 219 |Sibolga
# Processing Record 220 |Khatanga
# Processing Record 221 |Coihaique
# Processing Record 222 |Krasnyy Chikoy
# Processing Record 223 |Ararat
# Processing Record 224 |Diamantino
# Processing Record 225 |Khonuu
# City not found. Skipping
# Processing Record 226 |Norman Wells
# Processing Record 227 |Mogadishu
# Processing Record 228 |Vila Velha
# Processing Record 229 |Sapanta
# Processing Record 230 |Kieta
# Processing Record 231 |Bur Gabo
# City not found. Skipping
# Processing Record 232 |Hwange
# Processing Record 233 |Shelburne
# Processing Record 234 |Abong Mbang
# Processing Record 235 |Quang Ngai
# Processing Record 236 |Klaksvik
# Processing Record 237 |Sfantu Gheorghe
# Processing Record 238 |Esperance
# Processing Record 239 |Alotau
# City not found. Skipping
# Processing Record 240 |Nieuw Amsterdam
# Processing Record 241 |Ayan
# Processing Record 242 |Krasnoselkup
# Processing Record 243 |Sergach
# Processing Record 244 |Moose Factory
# Processing Record 245 |Yerbogachen
# Processing Record 246 |Belaya Gora
# Processing Record 247 |Bonthe
# Processing Record 248 |Lagoa
# Processing Record 249 |Dicabisagan
# Processing Record 250 |Yirol
# City not found. Skipping
# Processing Record 251 |Terrace Bay
# Processing Record 252 |Jos
# Processing Record 253 |Peleduy
# Processing Record 254 |Panama City
# Processing Record 255 |Xining
# Processing Record 256 |Astorga
# Processing Record 257 |Garmsar
# Processing Record 258 |Carutapera
# Processing Record 259 |Touros
# Processing Record 260 |Monforte De Lemos
# Processing Record 261 |Jacareacanga
# Processing Record 262 |Brownwood
# Processing Record 263 |Lata
# Processing Record 264 |Batsfjord
# Processing Record 265 |Port-Gentil
# Processing Record 266 |Harbour Breton
# Processing Record 267 |Utiroa
# City not found. Skipping
# Processing Record 268 |Daru
# Processing Record 269 |Miri
# Processing Record 270 |Lamu
# Processing Record 271 |Broome
# Processing Record 272 |Chokurdakh
# Processing Record 273 |Hemet
# Processing Record 274 |Puerto Quijarro
# Processing Record 275 |Saint-Jean-De-Maurienne
# Processing Record 276 |Prattville
# Processing Record 277 |Ponta Delgada
# Processing Record 278 |Umm Ruwabah
# City not found. Skipping
# Processing Record 279 |Najran
# Processing Record 280 |Paamiut
# Processing Record 281 |Faya
# Processing Record 282 |Jakar
# Processing Record 283 |Bubaque
# Processing Record 284 |Bud
# Processing Record 285 |Kemise
# Processing Record 286 |Meulaboh
# Processing Record 287 |Phalodi
# Processing Record 288 |Natal
# Processing Record 289 |Mahanje
# Processing Record 290 |Sao Joao Da Barra
# Processing Record 291 |Appiano
# City not found. Skipping
# Processing Record 292 |Vanimo
# Processing Record 293 |Georgetown
# Processing Record 294 |Waddan
# Processing Record 295 |Eenhana
# Processing Record 296 |Lasa
# Processing Record 297 |Toora-Khem
# Processing Record 298 |Viedma
# Processing Record 299 |Belle Fourche
# Processing Record 300 |Meadow Lake
# Processing Record 301 |Palmeira
# Processing Record 302 |Manado
# Processing Record 303 |Yantal
# Processing Record 304 |Vardo
# Processing Record 305 |Alyangula
# Processing Record 306 |Isangel
# Processing Record 307 |Phrai Bung
# City not found. Skipping
# Processing Record 308 |Puerto Leguizamo
# Processing Record 309 |Qaqortoq
# Processing Record 310 |Antsohihy
# Processing Record 311 |Samusu
# City not found. Skipping
# Processing Record 312 |Yaan
# Processing Record 313 |Kihei
# Processing Record 314 |Opuwo
# Processing Record 315 |Pontalina
# Processing Record 316 |Vysokogornyy
# Processing Record 317 |Iskateley
# Processing Record 318 |Edea
# Processing Record 319 |Akcaabat
# Processing Record 320 |Aklavik
# Processing Record 321 |Disraeli
# Processing Record 322 |Ayagoz
# Processing Record 323 |Dingle
# Processing Record 324 |Ye
# City not found. Skipping
# Processing Record 325 |Geraldton
# Processing Record 326 |Aguascalientes
# Processing Record 327 |Lopik
# Processing Record 328 |Pangnirtung
# Processing Record 329 |Namibe
# Processing Record 330 |Inhambane
# Processing Record 331 |Odesskoye
# Processing Record 332 |Aguimes
# Processing Record 333 |Santa Marta
# Processing Record 334 |Ouallam
# Processing Record 335 |Skalistyy
# City not found. Skipping
# Processing Record 336 |Maniitsoq
# Processing Record 337 |Anadyr
# Processing Record 338 |Hasaki
# Processing Record 339 |Port Hedland
# Processing Record 340 |Cidreira
# Processing Record 341 |Mananjary
# Processing Record 342 |Andijon
# Processing Record 343 |Haimen
# Processing Record 344 |Laguna
# Processing Record 345 |Vestmanna
# Processing Record 346 |Ulladulla
# Processing Record 347 |Te Anau
# Processing Record 348 |Tessalit
# Processing Record 349 |Asau
# Processing Record 350 |Evensk
# Processing Record 351 |Sakakah
# Processing Record 352 |Tura
# Processing Record 353 |Vigrestad
# Processing Record 354 |High Level
# Processing Record 355 |North Bend
# Processing Record 356 |Louis Trichardt
# Processing Record 357 |Urubicha
# Processing Record 358 |Pichataro
# Processing Record 359 |Constitucion
# Processing Record 360 |Porangatu
# Processing Record 361 |Narsaq
# Processing Record 362 |Victoria
# Processing Record 363 |Patnos
# Processing Record 364 |Muravlenko
# Processing Record 365 |Comodoro Rivadavia
# Processing Record 366 |Korla
# Processing Record 367 |Florianopolis
# Processing Record 368 |Vaitupu
# City not found. Skipping
# Processing Record 369 |Tsihombe
# City not found. Skipping
# Processing Record 370 |Kutum
# Processing Record 371 |Road Town
# Processing Record 372 |Khonsa
# Processing Record 373 |Cayenne
# Processing Record 374 |Falealupo
# City not found. Skipping
# Processing Record 375 |Rock Springs
# Processing Record 376 |College
# Processing Record 377 |Ahipara
# Processing Record 378 |Humaita
# Processing Record 379 |Sovetskiy
# Processing Record 380 |Fortuna
# Processing Record 381 |Batesville
# Processing Record 382 |Rio Gallegos
# Processing Record 383 |Ryotsu
# Processing Record 384 |Deputatskiy
# Processing Record 385 |Samarai
# Processing Record 386 |Hirado
# Processing Record 387 |Kota
# Processing Record 388 |Santa Barbara
# Processing Record 389 |Atar
# Processing Record 390 |Yumen
# Processing Record 391 |Sola
# Processing Record 392 |Bintulu
# Processing Record 393 |Kavaratti
# Processing Record 394 |Alhama De Murcia
# Processing Record 395 |Berlevag
# Processing Record 396 |Grand Gaube
# Processing Record 397 |Mabaruma
# Processing Record 398 |Cesme
# Processing Record 399 |Enumclaw
# Processing Record 400 |Fairbanks
# Processing Record 401 |Tezu
# Processing Record 402 |Mizdah
# Processing Record 403 |Port Arthur
# Processing Record 404 |Tahta
# Processing Record 405 |Kalabo
# Processing Record 406 |Caconda
# Processing Record 407 |Saskylakh
# Processing Record 408 |Bambanglipuro
# Processing Record 409 |San Ramon
# Processing Record 410 |Radnevo
# Processing Record 411 |Tyukhtet
# Processing Record 412 |Ayna
# Processing Record 413 |Dunedin
# Processing Record 414 |Shache
# Processing Record 415 |Mount Isa
# Processing Record 416 |Saint-Joseph
# Processing Record 417 |Shingu
# Processing Record 418 |Alofi
# Processing Record 419 |Ozernovskiy
# Processing Record 420 |Tres Palos
# Processing Record 421 |Karaul
# City not found. Skipping
# Processing Record 422 |Karpuninskiy
# City not found. Skipping
# Processing Record 423 |Grand River South East
# City not found. Skipping
# Processing Record 424 |San Quintin
# Processing Record 425 |Hay River
# Processing Record 426 |Tabou
# Processing Record 427 |Frontignan
# Processing Record 428 |Sisimiut
# Processing Record 429 |Nambour
# Processing Record 430 |Eyl
# Processing Record 431 |Elko
# Processing Record 432 |Moratuwa
# Processing Record 433 |Ugoofaaru
# Processing Record 434 |Poso
# Processing Record 435 |Chake Chake
# Processing Record 436 |Vila Franca Do Campo
# Processing Record 437 |Santiago Del Estero
# Processing Record 438 |Port Blair
# Processing Record 439 |Bandarbeyla
# Processing Record 440 |Swan Hill
# Processing Record 441 |Mount Barker
# Processing Record 442 |Luena
# Processing Record 443 |Le Port
# Processing Record 444 |Namatanai
# Processing Record 445 |Tuatapere
# Processing Record 446 |Vostok
# Processing Record 447 |Baracoa
# Processing Record 448 |Kailua
# Processing Record 449 |Lima
# Processing Record 450 |Rizhao
# Processing Record 451 |Champerico
# Processing Record 452 |Nadvoitsy
# Processing Record 453 |Meyungs
# City not found. Skipping
# Processing Record 454 |Redlands
# Processing Record 455 |Hermagor
# Processing Record 456 |Shenjiamen
# Processing Record 457 |Waterloo
# Processing Record 458 |Ust-Barguzin
# Processing Record 459 |Belfast
# Processing Record 460 |Aflu
# City not found. Skipping
# Processing Record 461 |Besskorbnaya
# Processing Record 462 |Prainha
# Processing Record 463 |Trairi
# Processing Record 464 |Talca
# Processing Record 465 |Flinders
# Processing Record 466 |Turukhansk
# Processing Record 467 |Belturbet
# Processing Record 468 |Zhezkazgan
# Processing Record 469 |Tabiauea
# City not found. Skipping
# Processing Record 470 |Kampong Thum
# Processing Record 471 |Oriximina
# Processing Record 472 |Livingston
# Processing Record 473 |Avigliana
# Processing Record 474 |Westerly
# Processing Record 475 |Santiago De Compostela
# Processing Record 476 |Arlit
# Processing Record 477 |Goderich
# Processing Record 478 |Porechye-Rybnoye
# Processing Record 479 |Hobyo
# Processing Record 480 |Acapulco
# Processing Record 481 |Umm Bab
# Processing Record 482 |Vung Tau
# Processing Record 483 |Bitung
# Processing Record 484 |Vestmannaeyjar
# Processing Record 485 |Hare Bay
# Processing Record 486 |Kloulklubed
# Processing Record 487 |Agva
# City not found. Skipping
# Processing Record 488 |Tilichiki
# Processing Record 489 |Attawapiskat
# City not found. Skipping
# Processing Record 490 |Independence
# Processing Record 491 |Nioro
# Processing Record 492 |Halalo
# City not found. Skipping
# Processing Record 493 |Hervey Bay
# Processing Record 494 |Veinticinco De Mayo
# Processing Record 495 |Novyy Urengoy
# Processing Record 496 |Byron Bay
# Processing Record 497 |Troitsko-Pechorsk
# Processing Record 498 |Hofn
# Processing Record 499 |Vao
# Processing Record 500 |Sahuaripa
# Processing Record 501 |Obama
# Processing Record 502 |Ngukurr
# City not found. Skipping
# Processing Record 503 |Hastings
# Processing Record 504 |Hualmay
# Processing Record 505 |Sovetskaya Gavan
# Processing Record 506 |Manacapuru
# Processing Record 507 |Ust-Maya
# Processing Record 508 |Higuey
# City not found. Skipping
# Processing Record 509 |Richards Bay
# Processing Record 510 |Mkushi
# Processing Record 511 |Abha
# Processing Record 512 |Riyadh
# Processing Record 513 |Temaraia
# City not found. Skipping
# Processing Record 514 |Naze
# Processing Record 515 |Hambantota
# Processing Record 516 |Chiredzi
# Processing Record 517 |Honningsvag
# Processing Record 518 |Yakeshi
# Processing Record 519 |Biloela
# Processing Record 520 |Zhigansk
# Processing Record 521 |Kanniyakumari
# Processing Record 522 |Bilibino
# Processing Record 523 |Talawdi
# City not found. Skipping
# Processing Record 524 |Ko Samui
# Processing Record 525 |Pevek
# Processing Record 526 |Pantayivka
# Processing Record 527 |Canico
# Processing Record 528 |Biltine
# Processing Record 529 |Tazovskiy
# Processing Record 530 |Svetlogorsk
# Processing Record 531 |Balimo
# City not found. Skipping
# Processing Record 532 |Yaypan
# Processing Record 533 |Horadiz
# Processing Record 534 |Dickson
# Processing Record 535 |Chapais
# Processing Record 536 |Fray Bentos
# Processing Record 537 |Tapaua
# City not found. Skipping
# Processing Record 538 |Sedelnikovo
# City not found. Skipping
# Processing Record 539 |Sawakin
# Processing Record 540 |Chardara
# Processing Record 541 |Glenwood Springs
# Processing Record 542 |Shaoyang
# Processing Record 543 |Aksu
# Processing Record 544 |Ilulissat
# Processing Record 545 |Soavinandriana
# Processing Record 546 |Kamenskoye
# City not found. Skipping
# Processing Record 547 |Imeni Zhelyabova
# Processing Record 548 |Oga
# Processing Record 549 |Kiyasovo
# Processing Record 550 |Olafsvik
# Processing Record 551 |Yunjinghong
# City not found. Skipping
# Processing Record 552 |Udachnyy
# Processing Record 553 |Xianyang
# Processing Record 554 |Lolua
# City not found. Skipping
# Processing Record 555 |Yatou
# Processing Record 556 |Flin Flon
# Processing Record 557 |Myaundzha
# Processing Record 558 |Iracoubo
# Processing Record 559 |Katherine
# Processing Record 560 |Kreuztal
# Processing Record 561 |Linxi
# Processing Record 562 |Moyobamba
# Processing Record 563 |Leningradskiy
# Processing Record 564 |Contamana
# Processing Record 565 |Gizo
# Processing Record 566 |Lalomanu
# City not found. Skipping
# Processing Record 567 |Pomerode
# Processing Record 568 |Ottumwa
# Processing Record 569 |Gornopravdinsk
# Processing Record 570 |Araouane
# Processing Record 571 |Goedereede
# Processing Record 572 |Karla
# Processing Record 573 |Beloha
# Processing Record 574 |Pemangkat
# Processing Record 575 |Lodwar
# Processing Record 576 |Goundi
# Processing Record 577 |La Palma
# Processing Record 578 |Ticusul
# City not found. Skipping
# Processing Record 579 |Santa Isabel
# Processing Record 580 |Camacha
# Processing Record 581 |Marcona
# City not found. Skipping
# Processing Record 582 |Lotofaga
# Processing Record 583 |Dakar
# Processing Record 584 |Kinkala
# Processing Record 585 |Panaba
# Processing Record 586 |Jiquipilas
# Processing Record 587 |Pahrump
# Processing Record 588 |Liberal
# Processing Record 589 |Cascais
# Processing Record 590 |Gigmoto
# Processing Record 591 |Fredericton
# Processing Record 592 |Neropolis
# Processing Record 593 |Gualaquiza
# Processing Record 594 |Sentyabrskiy
# City not found. Skipping
# Processing Record 595 |Ancud
# Processing Record 596 |Kawalu
# Processing Record 597 |Conde
# Processing Record 598 |Wewak
# Processing Record 599 |Mattru
# Processing Record 600 |Bengkulu
# Processing Record 601 |Shushtar
# Processing Record 602 |Doctor Pedro P. Pena
# City not found. Skipping
# Processing Record 603 |Sar-E Pul
# Processing Record 604 |Cumaribo
# City not found. Skipping
# Processing Record 605 |Neiafu
# Processing Record 606 |San Cristobal
# Processing Record 607 |Glenview
# Processing Record 608 |Puerto Madryn
# Processing Record 609 |Nelson Bay
# Processing Record 610 |Erenhot
# Processing Record 611 |Nogliki
# Processing Record 612 |Babanusah
# City not found. Skipping
# Processing Record 613 |Asyut
# Processing Record 614 |Waitati
# Processing Record 615 |Ewa Beach
# Processing Record 616 |Radford
# Processing Record 617 |Sindor
# Processing Record 618 |Yining
# Processing Record 619 |Ketchikan

# %%
# View Dataframe with fill empty columns
city_data.head()
# Out:
#           City Cloudiness Country Humidity    Lat    Lng Max Temp Wind Speed
# 0  La Macarena         43      CO       37   2.18 -73.78    92.12       5.77
# 1    Upernavik        100      GL       91  72.79 -56.15    27.82      10.65
# 2     Thompson         75      CA       53  55.74 -97.86     24.8       9.17
# 3  East London          0      ZA       64 -33.02  27.91    64.27       6.89
# 4  Provideniya         90      RU       80  64.38 -173.3     30.2      15.66

# %%
#Save Data to csv & display your updated DataFrame
city_data.to_csv("city_data.csv")

# %% [markdown]
# Convert Raw Data to DataFrame
# Export the city data into a .csv.
# Display the DataFrame

# %%
city_data.count()
# Out:
# City          620
# Cloudiness    620
# Country       620
# Humidity      620
# Lat           620
# Lng           620
# Max Temp      620
# Wind Speed    620
# dtype: int64

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 8 columns):
# City          620 non-null object
# Cloudiness    620 non-null object
# Country       620 non-null object
# Humidity      620 non-null object
# Lat           620 non-null object
# Lng           620 non-null object
# Max Temp      620 non-null object
# Wind Speed    620 non-null object
# dtypes: object(8)
# memory usage: 38.8+ KB

# %%
#drop rows with na values
city_data= city_data.dropna(how='any',axis=1) 
city_data.isnull().sum()
# Out:
# City          0
# Cloudiness    0
# Country       0
# Humidity      0
# Lat           0
# Lng           0
# Max Temp      0
# Wind Speed    0
# dtype: int64

# %%
#Change to float
city_data.info()
city_data['Lat'] = pd.to_numeric(city_data['Lat'],errors='coerce')
city_data['Lat']= city_data['Lat'].astype(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 8 columns):
# City          620 non-null object
# Cloudiness    620 non-null object
# Country       620 non-null object
# Humidity      620 non-null object
# Lat           620 non-null object
# Lng           620 non-null object
# Max Temp      620 non-null object
# Wind Speed    620 non-null object
# dtypes: object(8)
# memory usage: 38.8+ KB

# %%
#Change to float
city_data.info()
city_data['Max Temp'] = pd.to_numeric(city_data['Max Temp'],errors='coerce')
city_data['Max Temp']= city_data['Max Temp'].astype(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 8 columns):
# City          620 non-null object
# Cloudiness    620 non-null object
# Country       620 non-null object
# Humidity      620 non-null object
# Lat           566 non-null float64
# Lng           620 non-null object
# Max Temp      620 non-null object
# Wind Speed    620 non-null object
# dtypes: float64(1), object(7)
# memory usage: 38.8+ KB

# %%
#Change to float
city_data.info()
city_data['Humidity'] = pd.to_numeric(city_data['Humidity'],errors='coerce')
city_data['Humidity']= city_data['Humidity'].astype(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 8 columns):
# City          620 non-null object
# Cloudiness    620 non-null object
# Country       620 non-null object
# Humidity      620 non-null object
# Lat           566 non-null float64
# Lng           620 non-null object
# Max Temp      566 non-null float64
# Wind Speed    620 non-null object
# dtypes: float64(2), object(6)
# memory usage: 38.8+ KB

# %%
#Change to float
city_data.info()
city_data['Wind Speed'] = pd.to_numeric(city_data['Wind Speed'],errors='coerce')
city_data['Wind Speed']= city_data['Wind Speed'].astype(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 8 columns):
# City          620 non-null object
# Cloudiness    620 non-null object
# Country       620 non-null object
# Humidity      566 non-null float64
# Lat           566 non-null float64
# Lng           620 non-null object
# Max Temp      566 non-null float64
# Wind Speed    620 non-null object
# dtypes: float64(3), object(5)
# memory usage: 38.8+ KB

# %%
#Change to float
city_data.info()
city_data['Cloudiness'] = pd.to_numeric(city_data['Cloudiness'],errors='coerce')
city_data['Cloudiness']= city_data['Cloudiness'].astype(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 8 columns):
# City          620 non-null object
# Cloudiness    620 non-null object
# Country       620 non-null object
# Humidity      566 non-null float64
# Lat           566 non-null float64
# Lng           620 non-null object
# Max Temp      566 non-null float64
# Wind Speed    566 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 38.8+ KB

# %%
city_data= city_data.dropna(how='any')

# %% [markdown]
# Plotting the Data
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %% [markdown]
# Plotting the Data
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %%
#Latitude vs Temperature
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/CityLatitudevsMaxTemperature.png")

# Show plot
plt.show()

# %%
#Latitude vs Humidity Plot 
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/CityLatitudevsHumidity.png")

# Show plot
plt.show()

# %%
#Latitude vs Cloudiness Plot 
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/CityLatitudevsCloudiness.png")

# Show plot
plt.show()

# %%
#Latitude vs Wind Speed Plot
plt.scatter(city_data["Lat"], city_data['Wind Speed'], marker= "o" )

#Incorporate the other graph properties
plt.title("City Latitud vs Wind Speed Plot")
plt.ylabel("Latitude")
plt.xlabel("Wind Speed(%)")

#Save the figure
plt.savefig("Images/CityLatitudevsWindSpeed.png")

#Show plot
plt.show()
